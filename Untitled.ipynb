# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

# %%
my_data = pd.read_csv('Datasets/LAS_delays_Jan2019.csv')

# %%
my_data.head()
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 0  2019      1             1            2                NK
# 1  2019      1             1            2                NK
# 2  2019      1             1            2                NK
# 3  2019      1             1            2                NK
# 4  2019      1             1            2                NK
#
#    ORIGIN_AIRPORT_ID DEST  ARR_DEL15  CANCELLED CANCELLATION_CODE  DIVERTED  \
# 0              12889  ATL          0          0                 N         0
# 1              11298  LAS          0          0                 N         0
# 2              12889  SEA          0          0                 N         0
# 3              12892  LAS          1          0                 N         0
# 4              12889  DEN          0          0                 N         0
#
#    DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 0      1747              0              0          0               0
# ...

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29058 entries, 0 to 29057
# Data columns (total 17 columns):
# YEAR                   29058 non-null int64
# MONTH                  29058 non-null int64
# DAY_OF_MONTH           29058 non-null int64
# DAY_OF_WEEK            29058 non-null int64
# OP_UNIQUE_CARRIER      29058 non-null object
# ORIGIN_AIRPORT_ID      29058 non-null int64
# DEST                   29058 non-null object
# ARR_DEL15              29058 non-null int64
# CANCELLED              29058 non-null int64
# CANCELLATION_CODE      29058 non-null object
# DIVERTED               29058 non-null int64
# DISTANCE               29058 non-null int64
# CARRIER_DELAY          29058 non-null int64
# WEATHER_DELAY          29058 non-null int64
# NAS_DELAY              29058 non-null int64
# SECURITY_DELAY         29058 non-null int64
# LATE_AIRCRAFT_DELAY    29058 non-null int64
# dtypes: int64(14), object(3)
# memory usage: 3.8+ MB

# %%
# Create copy, checkpoint 
df = my_data.copy()

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 0  2019      1             1            2                NK
# 1  2019      1             1            2                NK
# 2  2019      1             1            2                NK
# 3  2019      1             1            2                NK
# 4  2019      1             1            2                NK
#
#    ORIGIN_AIRPORT_ID DEST  ARR_DEL15  CANCELLED CANCELLATION_CODE  DIVERTED  \
# 0              12889  ATL          0          0                 N         0
# 1              11298  LAS          0          0                 N         0
# 2              12889  SEA          0          0                 N         0
# 3              12892  LAS          1          0                 N         0
# 4              12889  DEN          0          0                 N         0
#
#    DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 0      1747              0              0          0               0
# ...

# %%
# Drop cancelled flights
df = df[df.CANCELLED != 1]

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 0  2019      1             1            2                NK
# 1  2019      1             1            2                NK
# 2  2019      1             1            2                NK
# 3  2019      1             1            2                NK
# 4  2019      1             1            2                NK
#
#    ORIGIN_AIRPORT_ID DEST  ARR_DEL15  CANCELLED CANCELLATION_CODE  DIVERTED  \
# 0              12889  ATL          0          0                 N         0
# 1              11298  LAS          0          0                 N         0
# 2              12889  SEA          0          0                 N         0
# 3              12892  LAS          1          0                 N         0
# 4              12889  DEN          0          0                 N         0
#
#    DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 0      1747              0              0          0               0
# ...

# %%
df = df.drop(['CANCELLED', 'CANCELLATION_CODE', 'DIVERTED'], axis=1)

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 0  2019      1             1            2                NK
# 1  2019      1             1            2                NK
# 2  2019      1             1            2                NK
# 3  2019      1             1            2                NK
# 4  2019      1             1            2                NK
#
#    ORIGIN_AIRPORT_ID DEST  ARR_DEL15  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0              12889  ATL          0      1747              0              0
# 1              11298  LAS          0      1055              0              0
# 2              12889  SEA          0       867              0              0
# 3              12892  LAS          1       236              0              0
# 4              12889  DEN          0       628              0              0
#
#    NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 0          0               0                    0
# ...
